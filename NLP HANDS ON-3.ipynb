# %%
import nltk
#Task 1: BASIC TEXT PROCESSING PIPELINE
text1 = '''The last stages of the self-rule struggle from the 1920s was characterized by Congress's adoption of Mohandas Karamchand Gandhi's policy of non-violence and civil disobedience, and several other campaigns. Nationalists like Subhash Chandra Bose, Bhagat Singh, Bagha Jatin, Surya Sen preached armed revolution to achieve self-rule. Poets and writers such as Vinayak Damodar Savarkar, Subramania Bharati, Rabindranath Tagore, Bankim Chandra Chattopadhyay and Kazi Nazrul Islam used literature, poetry, and speech as a tool for political awareness. Feminists like Sarojini Naidu promoted the emancipation of Indian women and their participation in national politics.[3] B. R. Ambedkar championed the cause of the disadvantaged sections of Indian society within the more significant self-rule movement.[4] The period of the World War II saw the peak of the campaigns by the Quit India Movement led by Congress and the Indian National Army movement led by Subhash Chandra Bose with the help of Japan.'''

for text in text1:
    sentences = nltk.sent_tokenize(text1)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# [('The', 'DT'), ('last', 'JJ'), ('stages', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('self-rule', 'JJ'), ('struggle', 'NN'), ('from', 'IN'), ('the', 'DT'), ('1920s', 'CD'), ('was', 'VBD'), ('characterized', 'VBN'), ('by', 'IN'), ('Congress', 'NNP'), ("'s", 'POS'), ('adoption', 'NN'), ('of', 'IN'), ('Mohandas', 'NNP'), ('Karamchand', 'NNP'), ('Gandhi', 'NNP'), ("'s", 'POS'), ('policy', 'NN'), ('of', 'IN'), ('non-violence', 'NN'), ('and', 'CC'), ('civil', 'JJ'), ('disobedience', 'NN'), (',', ','), ('and', 'CC'), ('several', 'JJ'), ('other', 'JJ'), ('campaigns', 'NNS'), ('.', '.')]
# [('Nationalists', 'NNS'), ('like', 'IN'), ('Subhash', 'NNP'), ('Chandra', 'NNP'), ('Bose', 'NNP'), (',', ','), ('Bhagat', 'NNP'), ('Singh', 'NNP'), (',', ','), ('Bagha', 'NNP'), ('Jatin', 'NNP'), (',', ','), ('Surya', 'NNP'), ('Sen', 'NNP'), ('preached', 'VBD'), ('armed', 'VBN'), ('revolution', 'NN'), ('to', 'TO'), ('achieve', 'VB'), ('self-rule', 'NN'), ('.', '.')]
# ...

# %%
#TASK-2 TweetTokenizer
from nltk.tokenize import TweetTokenizer
text = 'The party was soooooo fun :D #superfun'
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'party', 'was', 'soooooo', 'fun', ':D', '#superfun']

# %%
#TASK-3: SCRAPING DATA FROM WEB
from urllib import request 
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
len(raw)
raw[:75]
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)
type(tokens)
#HTML => ASCI => TEXT => VOCAB
# Out:
# list

# %%
#TASK-4: HANDLING TWEETS DATA 
import nltk
f = open('tweets1.txt','r')
text = f.read()
text1 = text.split()
text2 = nltk.Text(text1)
text2.concordance("good")
# Out:
# Displaying 17 of 17 matches:
# n The Signal premiere. Lotsa buyers. Good luck gang listening to the pocast ne
# so going to enjoy this shower. Feels good to have worked on a trail three time
# ose not my friend. it was not a very good day so I have a lot to do tomorrow..
# Oh why cheesecake why? You looked so good evil cake. Now metamucil. Reading: "
# utiful day so Im thinking to spend a good part of it outdoors.first stop at St
# g and ignoring my reaction to a very good friend getting fired. it's like a bi
# d HDH - url wrist sprain= damn pain. good thing it's not on my left hand. Bein
#  I bet I can throw farther than her. Good luck with that dude. Sure it will al
#  Choppers. first day of eid .. feels good Looking to buy a game called Shut th
# g. back from the ASLA 6 Congress. :) Good job ASLA CORE! I'm gonna need to ste
# tching the CNBC video of David Lear. Good job Sean! and now... off to Belize!
# ...

# %%
#Task - 5 SIMPLE TEXT CLASSIFICATION
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
gender_features('Obama')
# Out:
# {'last_letter': 'a'}

# %%
from nltk.corpus import names

# %%
#names.words()
#print(Len(names.words()))
labeled_names = ([(name,'male') for name in names.words('male.txt')] + [(name, 'female')  for name in names.words('female.txt')])

# %%
import random
random.shuffle(labeled_names)
labeled_names
# Out:
# [('Querida', 'female'),
#  ('Klarika', 'female'),
#  ('Dulcie', 'female'),
#  ('Reba', 'female'),
#  ('Coleman', 'male'),
#  ('Rosalynd', 'female'),
#  ('Jen', 'female'),
#  ('Orion', 'male'),
#  ('Adela', 'female'),
#  ('Berny', 'female'),
#  ('Jeanie', 'female'),
#  ('Winton', 'male'),
#  ('Erminie', 'female'),
#  ('Beale', 'male'),
#  ('Norene', 'female'),
#  ('Jonah', 'male'),
#  ('Klaus', 'male'),
#  ('Teresita', 'female'),
#  ('Malcah', 'female'),
#  ('Annie', 'female'),
#  ('Pavla', 'female'),
#  ('Adina', 'female'),
#  ('Vergil', 'male'),
#  ('Thaddius', 'male'),
#  ('Naoma', 'female'),
#  ('Gav', 'male'),
#  ('Kirsten', 'female'),
#  ('Torey', 'female'),
#  ('Kendall', 'male'),
#  ('Silvia', 'female'),
#  ('JoAnne', 'female'),
#  ('Kai', 'female'),
#  ('Ulric', 'male'),
#  ('Fara', 'female'),
#  ('Drea', 'female'),
#  ('Elvis', 'male'),
#  ('Cassandre', 'female'),
#  ('Prentice', 'male'),
#  ('Willamina', 'female'),
#  ('Griffith', 'male'),
#  ('Cristi', 'female'),
# ...

# %%
import random
random.shuffle(labeled_names)
featuresets = [(gender_features(n), gender) for (n,gender) in labeled_names]

# %%
train_set, test_set = featuresets[5000:], featuresets[:2000]
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('shashank'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('satya'))
# Out:
# 'female'

# %%
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 0.7485

# %%
#TASK-6 COUNT VECTORIZER
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(binary=True)
corpus = ["Tessaract is good optical character recognition engine  ", "optical character recognition is significant "]

# %%
vect.fit(corpus)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vocab = vect.vocabulary_
for key in sorted(vocab.keys()):
    print("{}:{}".format(key, vocab[key]))
# Out:
# character:0
# engine:1
# good:2
# is:3
# optical:4
# recognition:5
# significant:6
# tessaract:7

# %%
print(vect.transform(["This is a good optical illusion"]).toarray())
# Out:
# [[0 0 1 1 1 0 0 0]]

# %%
#Finding similarity between the documents
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vect.transform(["Google Cloud Vision is a character recognition engine"]).toarray(), vect.transform(["OCR is an optical character recognition engine"]).toarray())
print(similarity)
# Out:
# [[0.89442719]]

# %%
from nltk.stem import PorterStemmer
a = """Sachin Ramesh Tendulkar (/ˌsʌtʃɪn tɛnˈduːlkər/ (About this soundlisten); born 24 April 1973) is a former international cricketer from India and a former captain of the Indian national team. He is widely regarded as one of the greatest batsmen in the history of cricket.[5] He is the highest run scorer of all time in International cricket. Considered as the world's most prolific batsman of all time,[6] he is the only player to have scored one hundred international centuries, the first batsman to score a double century in a One Day International (ODI), the holder of the record for the most runs in both Test and ODI cricket, and the only player to complete more than 30,000 runs in international cricket.[7]
Tendulkar took up cricket at the age of eleven, made his Test debut on 15 November 1989 against Pakistan in Karachi at the age of sixteen, and went on to represent Mumbai domestically and India internationally for close to twenty-four years. In 2002, halfway through his career, Wisden Cricketers' Almanack ranked him the second greatest Test batsman of all time, behind Don Bradman, and the second greatest ODI batsman of all time, behind Viv Richards.[8] Later in his career, Tendulkar was a part of the Indian team that won the 2011 World Cup, his first win in six World Cup appearances for India.[9] He had previously been named "Player of the Tournament" at the 2003 edition of the tournament, held in South Africa. In 2013, he was the only Indian cricketer included in an all-time Test World XI named to mark the 150th anniversary of Wisden Cricketers' Almanack.[10][11][12] He is affectionately known as Little Master or Master Blaster.[13][14][15][16]
Tendulkar received the Arjuna Award in 1994 for his outstanding sporting achievement, the Rajiv Gandhi Khel Ratna award in 1997, India's highest sporting honour, and the Padma Shri and Padma Vibhushan awards in 1999 and 2008, respectively, India's fourth and second highest civilian awards.[17] After a few hours of his final match on 16 November 2013, the Prime Minister's Office announced the decision to award him the Bharat Ratna, India's highest civilian award.[18][19] He is the youngest recipient to date and the first ever sportsperson to receive the award.[20][21] He also won the 2010 Sir Garfield Sobers Trophy for cricketer of the year at the ICC awards.[22] In 2012, Tendulkar was nominated to the Rajya Sabha, the upper house of the Parliament of India.[23] He was also the first sportsperson and the first person without an aviation background to be awarded the honorary rank of group captain by the Indian Air Force.[24] In 2012, he was named an Honorary Member of the Order of Australia.[25][26]
In 2010, Time magazine included Sachin in its annual Time 100 list as one of the "Most Influential People in the World".[27] In December 2012, Tendulkar announced his retirement from ODIs.[28] He retired from Twenty20 cricket in October 2013[29] and subsequently retired from all forms of cricket on 16 November 2013 after playing his 200th Test match, against the West Indies in Mumbai's Wankhede Stadium.[30] Tendulkar played 664 international cricket matches in total, scoring 34,357 runs.[7]"""
stemmer = PorterStemmer()
example = a
example = [stemmer.stem(token) for token in example.split(" ")]
print (" ".join(example))
print("\n")
print("\n")

b = """Mahendra Singh Dhoni (About this soundpronunciation (help·info) born 7 July 1981), is a former Indian international cricketer who captained the Indian national team in limited-overs formats from 2007 to 2016 and in Test cricket from 2008 to 2014. Under his captaincy, India won the 2007 ICC World Twenty20, the 2010 and 2016 Asia Cups, the 2011 ICC Cricket World Cup and the 2013 ICC Champions Trophy. A right-handed middle-order batsman and wicket-keeper, Dhoni is one of the highest run scorers in One Day Internationals (ODIs) with more than 10,000 runs scored and is considered an effective "finisher" in limited-overs formats.[2][3][4] He is also regarded by some as one of the best wicket-keepers and captains in modern limited-overs international cricket.[5]
He made his ODI debut in December 2004 against Bangladesh, and played his first Test a year later against Sri Lanka. Dhoni has been the recipient of many awards, including the ICC ODI Player of the Year award in 2008 and 2009 (the first player to win the award twice), the Rajiv Gandhi Khel Ratna award in 2007, the Padma Shri, India's fourth highest civilian honour, in 2009 and the Padma Bhushan, India's third highest civilian honour, in 2018.[6] He was named as the captain of the ICC World Test XI in 2009, 2010 and 2013. He has also been selected a record 8 times in ICC World ODI XI teams, 5 times as captain. The Indian Territorial Army conferred the honorary rank of Lieutenant Colonel[7] to Dhoni on 1 November 2011. He is the second Indian cricketer after Kapil Dev to receive this honour.
Dhoni also holds numerous captaincy records such as the most wins by an Indian captain in ODIs and T20Is, and most back-to-back wins by an Indian captain in ODIs. He took over the ODI captaincy from Rahul Dravid in 2007 and led the team to its first-ever bilateral ODI series wins in Sri Lanka and New Zealand. In June 2013, when India defeated England in the final of the Champions Trophy in England, Dhoni became the first captain to win all three ICC limited-overs trophies (World Cup, Champions Trophy and the World Twenty20). After taking up the Test captaincy in 2008, he led the team to series wins in New Zealand and the West Indies, and the Border-Gavaskar Trophy in 2008, 2010 and 2013. In 2009, Dhoni also led the Indian team to number one position for the first time in the ICC Test rankings.
In 2013, under his captaincy, India became the first team in more than 40 years to whitewash Australia in a Test series. In the Indian Premier League, he captained the Chennai Super Kings to victory at the 2010, 2011 and 2018 seasons, along with wins in the 2010 and 2014 editions of Champions League Twenty20. In 2011, Time magazine included Dhoni in its annual Time 100 list as one of the "Most Influential People in the World."[8] Dhoni holds the post of Vice-President of India Cements Ltd., after resigning from Air India. India Cements is the owner of the IPL team Chennai Super Kings, and Dhoni has been its captain since the first IPL season.[9][10] He announced his retirement from Tests on 30 December 2014.[11]
In 2012, SportsPro rated Dhoni as the sixteenth most marketable athlete in the world.[12] Dhoni is the co-owner of Indian Super League team Chennaiyin FC.[13] In June 2015, Forbes ranked Dhoni at 23rd in the list of highest paid athletes in the world, estimating his earnings at US$31 million.[14] In 2016, a biopic M.S. Dhoni: The Untold Story was made about his life and cricketing career up to the Indian team's win at the 2011 Cricket World Cup.
MS Dhoni announced his retirement from international cricket on 15 August 2020."""
stemmer1 = PorterStemmer()
example1 = b
example1 = [stemmer1.stem(token1) for token1 in example1.split(" ")]
print (" ".join(example1))
# Out:
# sachin ramesh tendulkar (/ˌsʌtʃɪn tɛnˈduːlkər/ (about thi soundlisten); born 24 april 1973) is a former intern cricket from india and a former captain of the indian nation team. He is wide regard as one of the greatest batsmen in the histori of cricket.[5] He is the highest run scorer of all time in intern cricket. consid as the world' most prolif batsman of all time,[6] he is the onli player to have score one hundr intern centuries, the first batsman to score a doubl centuri in a one day intern (odi), the holder of the record for the most run in both test and odi cricket, and the onli player to complet more than 30,000 run in intern cricket.[7]
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(binary=True)
a = """Sachin Ramesh Tendulkar (/ˌsʌtʃɪn tɛnˈduːlkər/ (About this soundlisten); born 24 April 1973) is a former international cricketer from India and a former captain of the Indian national team. He is widely regarded as one of the greatest batsmen in the history of cricket.[5] He is the highest run scorer of all time in International cricket. Considered as the world's most prolific batsman of all time,[6] he is the only player to have scored one hundred international centuries, the first batsman to score a double century in a One Day International (ODI), the holder of the record for the most runs in both Test and ODI cricket, and the only player to complete more than 30,000 runs in international cricket.[7]
Tendulkar took up cricket at the age of eleven, made his Test debut on 15 November 1989 against Pakistan in Karachi at the age of sixteen, and went on to represent Mumbai domestically and India internationally for close to twenty-four years. In 2002, halfway through his career, Wisden Cricketers' Almanack ranked him the second greatest Test batsman of all time, behind Don Bradman, and the second greatest ODI batsman of all time, behind Viv Richards.[8] Later in his career, Tendulkar was a part of the Indian team that won the 2011 World Cup, his first win in six World Cup appearances for India.[9] He had previously been named "Player of the Tournament" at the 2003 edition of the tournament, held in South Africa. In 2013, he was the only Indian cricketer included in an all-time Test World XI named to mark the 150th anniversary of Wisden Cricketers' Almanack.[10][11][12] He is affectionately known as Little Master or Master Blaster.[13][14][15][16]
Tendulkar received the Arjuna Award in 1994 for his outstanding sporting achievement, the Rajiv Gandhi Khel Ratna award in 1997, India's highest sporting honour, and the Padma Shri and Padma Vibhushan awards in 1999 and 2008, respectively, India's fourth and second highest civilian awards.[17] After a few hours of his final match on 16 November 2013, the Prime Minister's Office announced the decision to award him the Bharat Ratna, India's highest civilian award.[18][19] He is the youngest recipient to date and the first ever sportsperson to receive the award.[20][21] He also won the 2010 Sir Garfield Sobers Trophy for cricketer of the year at the ICC awards.[22] In 2012, Tendulkar was nominated to the Rajya Sabha, the upper house of the Parliament of India.[23] He was also the first sportsperson and the first person without an aviation background to be awarded the honorary rank of group captain by the Indian Air Force.[24] In 2012, he was named an Honorary Member of the Order of Australia.[25][26]
In 2010, Time magazine included Sachin in its annual Time 100 list as one of the "Most Influential People in the World".[27] In December 2012, Tendulkar announced his retirement from ODIs.[28] He retired from Twenty20 cricket in October 2013[29] and subsequently retired from all forms of cricket on 16 November 2013 after playing his 200th Test match, against the West Indies in Mumbai's Wankhede Stadium.[30] Tendulkar played 664 international cricket matches in total, scoring 34,357 runs.[7]"""
b = """Mahendra Singh Dhoni (About this soundpronunciation (help·info) born 7 July 1981), is a former Indian international cricketer who captained the Indian national team in limited-overs formats from 2007 to 2016 and in Test cricket from 2008 to 2014. Under his captaincy, India won the 2007 ICC World Twenty20, the 2010 and 2016 Asia Cups, the 2011 ICC Cricket World Cup and the 2013 ICC Champions Trophy. A right-handed middle-order batsman and wicket-keeper, Dhoni is one of the highest run scorers in One Day Internationals (ODIs) with more than 10,000 runs scored and is considered an effective "finisher" in limited-overs formats.[2][3][4] He is also regarded by some as one of the best wicket-keepers and captains in modern limited-overs international cricket.[5]
He made his ODI debut in December 2004 against Bangladesh, and played his first Test a year later against Sri Lanka. Dhoni has been the recipient of many awards, including the ICC ODI Player of the Year award in 2008 and 2009 (the first player to win the award twice), the Rajiv Gandhi Khel Ratna award in 2007, the Padma Shri, India's fourth highest civilian honour, in 2009 and the Padma Bhushan, India's third highest civilian honour, in 2018.[6] He was named as the captain of the ICC World Test XI in 2009, 2010 and 2013. He has also been selected a record 8 times in ICC World ODI XI teams, 5 times as captain. The Indian Territorial Army conferred the honorary rank of Lieutenant Colonel[7] to Dhoni on 1 November 2011. He is the second Indian cricketer after Kapil Dev to receive this honour.
Dhoni also holds numerous captaincy records such as the most wins by an Indian captain in ODIs and T20Is, and most back-to-back wins by an Indian captain in ODIs. He took over the ODI captaincy from Rahul Dravid in 2007 and led the team to its first-ever bilateral ODI series wins in Sri Lanka and New Zealand. In June 2013, when India defeated England in the final of the Champions Trophy in England, Dhoni became the first captain to win all three ICC limited-overs trophies (World Cup, Champions Trophy and the World Twenty20). After taking up the Test captaincy in 2008, he led the team to series wins in New Zealand and the West Indies, and the Border-Gavaskar Trophy in 2008, 2010 and 2013. In 2009, Dhoni also led the Indian team to number one position for the first time in the ICC Test rankings.
In 2013, under his captaincy, India became the first team in more than 40 years to whitewash Australia in a Test series. In the Indian Premier League, he captained the Chennai Super Kings to victory at the 2010, 2011 and 2018 seasons, along with wins in the 2010 and 2014 editions of Champions League Twenty20. In 2011, Time magazine included Dhoni in its annual Time 100 list as one of the "Most Influential People in the World."[8] Dhoni holds the post of Vice-President of India Cements Ltd., after resigning from Air India. India Cements is the owner of the IPL team Chennai Super Kings, and Dhoni has been its captain since the first IPL season.[9][10] He announced his retirement from Tests on 30 December 2014.[11]
In 2012, SportsPro rated Dhoni as the sixteenth most marketable athlete in the world.[12] Dhoni is the co-owner of Indian Super League team Chennaiyin FC.[13] In June 2015, Forbes ranked Dhoni at 23rd in the list of highest paid athletes in the world, estimating his earnings at US$31 million.[14] In 2016, a biopic M.S. Dhoni: The Untold Story was made about his life and cricketing career up to the Indian team's win at the 2011 Cricket World Cup.
MS Dhoni announced his retirement from international cricket on 15 August 2020."""
corpus = [a,b]

# %%
vect.fit(corpus)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vocab = vect.vocabulary_
for key in sorted(vocab.keys()):
    print("{}:{}".format(key, vocab[key]))
# Out:
# 000:0
# 10:1
# 100:2
# 11:3
# 12:4
# 13:5
# 14:6
# 15:7
# 150th:8
# 16:9
# 17:10
# 18:11
# 19:12
# 1973:13
# 1981:14
# 1989:15
# 1994:16
# 1997:17
# 1999:18
# 20:19
# 2002:20
# 2003:21
# 2004:22
# 2007:23
# 2008:24
# 2009:25
# 200th:26
# 2010:27
# 2011:28
# 2012:29
# 2013:30
# 2014:31
# 2015:32
# 2016:33
# 2018:34
# 2020:35
# 21:36
# 22:37
# 23:38
# 23rd:39
# 24:40
# 25:41
# 26:42
# 27:43
# 28:44
# 29:45
# 30:46
# 31:47
# 34:48
# 357:49
# 40:50
# 664:51
# about:52
# achievement:53
# affectionately:54
# africa:55
# after:56
# against:57
# age:58
# air:59
# all:60
# almanack:61
# along:62
# also:63
# an:64
# and:65
# anniversary:66
# announced:67
# annual:68
# appearances:69
# april:70
# arjuna:71
# army:72
# as:73
# asia:74
# at:75
# athlete:76
# athletes:77
# august:78
# australia:79
# aviation:80
# award:81
# awarded:82
# awards:83
# back:84
# background:85
# bangladesh:86
# batsman:87
# batsmen:88
# be:89
# became:90
# been:91
# behind:92
# best:93
# bharat:94
# bhushan:95
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vect.transform([a]).toarray(), vect.transform([b]).toarray())
print(similarity)
# Out:
# [[0.46668102]]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(binary=True)
c = """sachin ramesh tendulkar (/ˌsʌtʃɪn tɛnˈduːlkər/ (about thi soundlisten); born 24 april 1973) is a former intern cricket from india and a former captain of the indian nation team. He is wide regard as one of the greatest batsmen in the histori of cricket.[5] He is the highest run scorer of all time in intern cricket. consid as the world' most prolif batsman of all time,[6] he is the onli player to have score one hundr intern centuries, the first batsman to score a doubl centuri in a one day intern (odi), the holder of the record for the most run in both test and odi cricket, and the onli player to complet more than 30,000 run in intern cricket.[7]
tendulkar took up cricket at the age of eleven, made hi test debut on 15 novemb 1989 against pakistan in karachi at the age of sixteen, and went on to repres mumbai domest and india intern for close to twenty-four years. In 2002, halfway through hi career, wisden cricketers' almanack rank him the second greatest test batsman of all time, behind don bradman, and the second greatest odi batsman of all time, behind viv richards.[8] later in hi career, tendulkar wa a part of the indian team that won the 2011 world cup, hi first win in six world cup appear for india.[9] He had previous been name "player of the tournament" at the 2003 edit of the tournament, held in south africa. In 2013, he wa the onli indian cricket includ in an all-tim test world XI name to mark the 150th anniversari of wisden cricketers' almanack.[10][11][12] He is affection known as littl master or master blaster.[13][14][15][16]
tendulkar receiv the arjuna award in 1994 for hi outstand sport achievement, the rajiv gandhi khel ratna award in 1997, india' highest sport honour, and the padma shri and padma vibhushan award in 1999 and 2008, respectively, india' fourth and second highest civilian awards.[17] after a few hour of hi final match on 16 novemb 2013, the prime minister' offic announc the decis to award him the bharat ratna, india' highest civilian award.[18][19] He is the youngest recipi to date and the first ever sportsperson to receiv the award.[20][21] He also won the 2010 sir garfield sober trophi for cricket of the year at the icc awards.[22] In 2012, tendulkar wa nomin to the rajya sabha, the upper hous of the parliament of india.[23] He wa also the first sportsperson and the first person without an aviat background to be award the honorari rank of group captain by the indian air force.[24] In 2012, he wa name an honorari member of the order of australia.[25][26]
in 2010, time magazin includ sachin in it annual time 100 list as one of the "most influenti peopl in the world".[27] In decemb 2012, tendulkar announc hi retir from odis.[28] He retir from twenty20 cricket in octob 2013[29] and subsequ retir from all form of cricket on 16 novemb 2013 after play hi 200th test match, against the west indi in mumbai' wankhed stadium.[30] tendulkar play 664 intern cricket match in total, score 34,357 runs.[7]"""
d = """mahendra singh dhoni (about thi soundpronunci (help·info) born 7 juli 1981), is a former indian intern cricket who captain the indian nation team in limited-ov format from 2007 to 2016 and in test cricket from 2008 to 2014. under hi captaincy, india won the 2007 icc world twenty20, the 2010 and 2016 asia cups, the 2011 icc cricket world cup and the 2013 icc champion trophy. A right-hand middle-ord batsman and wicket-keeper, dhoni is one of the highest run scorer in one day intern (odis) with more than 10,000 run score and is consid an effect "finisher" in limited-ov formats.[2][3][4] He is also regard by some as one of the best wicket-keep and captain in modern limited-ov intern cricket.[5]
h made hi odi debut in decemb 2004 against bangladesh, and play hi first test a year later against sri lanka. dhoni ha been the recipi of mani awards, includ the icc odi player of the year award in 2008 and 2009 (the first player to win the award twice), the rajiv gandhi khel ratna award in 2007, the padma shri, india' fourth highest civilian honour, in 2009 and the padma bhushan, india' third highest civilian honour, in 2018.[6] He wa name as the captain of the icc world test XI in 2009, 2010 and 2013. He ha also been select a record 8 time in icc world odi XI teams, 5 time as captain. the indian territori armi confer the honorari rank of lieuten colonel[7] to dhoni on 1 novemb 2011. He is the second indian cricket after kapil dev to receiv thi honour.
dhoni also hold numer captainci record such as the most win by an indian captain in odi and t20is, and most back-to-back win by an indian captain in odis. He took over the odi captainci from rahul dravid in 2007 and led the team to it first-ev bilater odi seri win in sri lanka and new zealand. In june 2013, when india defeat england in the final of the champion trophi in england, dhoni becam the first captain to win all three icc limited-ov trophi (world cup, champion trophi and the world twenty20). after take up the test captainci in 2008, he led the team to seri win in new zealand and the west indies, and the border-gavaskar trophi in 2008, 2010 and 2013. In 2009, dhoni also led the indian team to number one posit for the first time in the icc test rankings.
in 2013, under hi captaincy, india becam the first team in more than 40 year to whitewash australia in a test series. In the indian premier league, he captain the chennai super king to victori at the 2010, 2011 and 2018 seasons, along with win in the 2010 and 2014 edit of champion leagu twenty20. In 2011, time magazin includ dhoni in it annual time 100 list as one of the "most influenti peopl in the world."[8] dhoni hold the post of vice-presid of india cement ltd., after resign from air india. india cement is the owner of the ipl team chennai super kings, and dhoni ha been it captain sinc the first ipl season.[9][10] He announc hi retir from test on 30 decemb 2014.[11]
in 2012, sportspro rate dhoni as the sixteenth most market athlet in the world.[12] dhoni is the co-own of indian super leagu team chennaiyin fc.[13] In june 2015, forb rank dhoni at 23rd in the list of highest paid athlet in the world, estim hi earn at us$31 million.[14] In 2016, a biopic m.s. dhoni: the untold stori wa made about hi life and cricket career up to the indian team' win at the 2011 cricket world cup.
m dhoni announc hi retir from intern cricket on 15 august 2020."""
corpus = [c,d]

# %%
vect.fit(corpus)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vocab = vect.vocabulary_
for key in sorted(vocab.keys()):
    print("{}:{}".format(key, vocab[key]))
# Out:
# 000:0
# 10:1
# 100:2
# 11:3
# 12:4
# 13:5
# 14:6
# 15:7
# 150th:8
# 16:9
# 17:10
# 18:11
# 19:12
# 1973:13
# 1981:14
# 1989:15
# 1994:16
# 1997:17
# 1999:18
# 20:19
# 2002:20
# 2003:21
# 2004:22
# 2007:23
# 2008:24
# 2009:25
# 200th:26
# 2010:27
# 2011:28
# 2012:29
# 2013:30
# 2014:31
# 2015:32
# 2016:33
# 2018:34
# 2020:35
# 21:36
# 22:37
# 23:38
# 23rd:39
# 24:40
# 25:41
# 26:42
# 27:43
# 28:44
# 29:45
# 30:46
# 31:47
# 34:48
# 357:49
# 40:50
# 664:51
# about:52
# achievement:53
# affection:54
# africa:55
# after:56
# against:57
# age:58
# air:59
# all:60
# almanack:61
# along:62
# also:63
# an:64
# and:65
# anniversari:66
# announc:67
# annual:68
# appear:69
# april:70
# arjuna:71
# armi:72
# as:73
# asia:74
# at:75
# athlet:76
# august:77
# australia:78
# aviat:79
# award:80
# awards:81
# back:82
# background:83
# bangladesh:84
# batsman:85
# batsmen:86
# be:87
# becam:88
# been:89
# behind:90
# best:91
# bharat:92
# bhushan:93
# bilater:94
# biopic:95
# blaster:96
# border:97
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vect.transform([a]).toarray(), vect.transform([b]).toarray())
print(similarity)
# Out:
# [[0.50171236]]

# %%
import spacy
sp = spacy.load('en_core_web_sm')

sen = sp(u'Manchester United is looking to sign Harry Kane for $90 million')
print(sen.ents)
# Out:
# (Manchester United, Harry Kane, $90 million)

# %%
for entity in sen.ents:
    print(entity.text + ' - ' + entity.label_ + ' - ' + str(spacy.explain(entity.label_)))
# Out:
# Manchester United - ORG - Companies, agencies, institutions, etc.
# Harry Kane - PERSON - People, including fictional
# $90 million - MONEY - Monetary values, including unit
